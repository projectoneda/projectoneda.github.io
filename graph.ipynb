# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import pandas as pd
import matplotlib

# %%
year_stock_data = pd.read_csv('csv/year_stock_data.csv')

year_date = year_stock_data.Date
year_open = year_stock_data.Open

# %%
# JP Morgan 
jp = pd.read_csv('csv/jp.csv')
jp_date = jp.Date
jp_open = jp.Open

fig, ax1 = plt.subplots(figsize=(15,5), facecolor=('#35424A'))

color = '#E8491D'
ax1.plot(jp_date, jp_open, color=color)
ax1.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
ax1.set_yticklabels([])

ax2 = ax1.twinx() 

color = '#35424A'
ax2.plot(year_date, year_open, color=color)
ax2.set_yticklabels([])

plt.savefig("graphs/jp")

# %%
# Goldman Sachs
gs = pd.read_csv('csv/gs.csv')
gs_date = gs.Date
gs_open = gs.Open

fig, ax1 = plt.subplots(figsize=(15,5), facecolor=('#35424A'))

color = '#E8491D'
ax1.plot(gs_date, gs_open, color=color)
ax1.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
ax1.set_yticklabels([])

ax2 = ax1.twinx() 

color = '#35424A'
ax2.plot(year_date, year_open, color=color)
ax2.set_yticklabels([])

plt.savefig("graphs/gs")

# %%
# UBS
ubs = pd.read_csv('csv/ubs.csv')
ubs_date = ubs.Date
ubs_open = ubs.Open

fig, ax1 = plt.subplots(figsize=(15,5), facecolor=('#35424A'))

color = '#E8491D'
ax1.plot(ubs_date, ubs_open, color=color)
ax1.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
ax1.set_yticklabels([])

ax2 = ax1.twinx() 

color = '#35424A'
ax2.plot(year_date, year_open, color=color)
ax2.set_yticklabels([])

plt.savefig("graphs/ubs")

# %%
# Wells Fargo
wf = pd.read_csv('csv/wf.csv')
wf_date = wf.Date
wf_open = wf.Open

fig, ax1 = plt.subplots(figsize=(15,5), facecolor=('#35424A'))

color = '#E8491D'
ax1.plot(wf_date, wf_open, color=color)
ax1.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
ax1.set_yticklabels([])

ax2 = ax1.twinx() 

color = '#35424A'
ax2.plot(year_date, year_open, color=color)
ax2.set_yticklabels([])

plt.savefig("graphs/wf")

# %%
# Bank of America
bac = pd.read_csv('csv/bac.csv')
bac_date = bac.Date
bac_open = bac.Open

fig, ax1 = plt.subplots(figsize=(15,5), facecolor=('#35424A'))

color = '#E8491D'
ax1.plot(bac_date, bac_open, color=color)
ax1.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
ax1.set_yticklabels([])

ax2 = ax1.twinx() 

color = '#35424A'
ax2.plot(year_date, year_open, color=color)
ax2.set_yticklabels([])

plt.savefig("graphs/bac")
